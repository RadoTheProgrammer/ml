# %%
import pandas as pd

myDataset = pd.read_csv('Data/ozone.csv')

# %%
myDataset["Resultat"] = False
myDataset
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG  Resultat
# 0    -0.64350     False
# 1    -0.04996     False
# ...

# %%
myDataset["Pow2_O3obs"] = myDataset["O3obs"]**2
myDataset
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG  Resultat  Pow2_O3obs
# 0    -0.64350     False        8281
# ...

# %%
myDataset["Total"] = myDataset.iloc[:,5:7].sum(axis=1) #axis=1 pour sommer les colonnes par ligne
myDataset
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG  Resultat  Pow2_O3obs  Total
# 0    -0.64350     False        8281  2.026
# ...

# %%
myDataset["Total"] = myDataset.loc[:,["NO2","NO"]].sum(axis=1)
myDataset
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG  Resultat  Pow2_O3obs  Total
# 0    -0.64350     False        8281  2.026
# ...

# %%
columns=list(myDataset.columns)
newDataset = myDataset[columns[0:7]+[columns[-1]]+columns[7:-1]]
newDataset
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO  Total STATION  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424  2.026     Aix
# 1        1    100   104.6   20.2  0.00881  2.121  0.531  2.652     Aix
# 2        0     82   103.6   17.4  0.00951  1.657  0.467  2.124     Aix
# 3        0     94    94.8   18.8  0.00855  2.350  0.701  3.051     Aix
# 4        0    107    99.0   23.7  0.00731  1.653  0.452  2.105     Aix
# ...    ...    ...     ...    ...      ...    ...    ...    ...     ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431  5.274     Pla
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411  3.577     Pla
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942  9.291     Pla
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199  2.300     Pla
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202  2.492     Pla
#
#       VentMOD  VentANG  Resultat  Pow2_O3obs
# 0      9.5000 -0.64350     False        8281
# ...

# %%
myDataset=myDataset.drop(columns=["Pow2_O3obs","Total"])
myDataset
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847  1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881  2.121  0.531     Aix   8.0100
# 2        0     82   103.6   17.4  0.00951  1.657  0.467     Aix   9.3771
# 3        0     94    94.8   18.8  0.00855  2.350  0.701     Aix   9.4578
# 4        0    107    99.0   23.7  0.00731  1.653  0.452     Aix   7.8791
# ...    ...    ...     ...    ...      ...    ...    ...     ...      ...
# 1036     0    116   233.6   22.1  0.01048  4.843  0.431     Pla   4.8052
# 1037     0     60   162.5   15.8  0.00789  3.166  0.411     Pla   2.7203
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG  Resultat
# 0    -0.64350     False
# 1    -0.04996     False
# ...

# %%
myDataset["Resultat"] = False
columns = list(myDataset.columns)
myDataset = myDataset[columns[:3]+[columns[-1]]+columns[3:-1]]
dif=abs(myDataset["O3obs"]-myDataset["MOCAGE"])
myDataset.loc[dif < 2.5, "Resultat"] = True
myDataset
# Out:
#       JOUR  O3obs  MOCAGE  Resultat  TEMPE    RMH2O    NO2     NO STATION  \
# 0        1     91    93.2      True   21.5  0.00847  1.602  0.424     Aix
# 1        1    100   104.6     False   20.2  0.00881  2.121  0.531     Aix
# 2        0     82   103.6     False   17.4  0.00951  1.657  0.467     Aix
# 3        0     94    94.8      True   18.8  0.00855  2.350  0.701     Aix
# 4        0    107    99.0     False   23.7  0.00731  1.653  0.452     Aix
# ...    ...    ...     ...       ...    ...      ...    ...    ...     ...
# 1036     0    116   233.6     False   22.1  0.01048  4.843  0.431     Pla
# 1037     0     60   162.5     False   15.8  0.00789  3.166  0.411     Pla
# 1038     0     74   198.4     False   16.2  0.00811  8.349  0.942     Pla
# 1039     0    121   191.7     False   16.4  0.00722  2.101  0.199     Pla
# 1040     1     93   221.2     False   16.7  0.00919  2.290  0.202     Pla
#
#       VentMOD  VentANG
# 0      9.5000 -0.64350
# 1      8.0100 -0.04996
# ...

# %%
myDataset = myDataset.drop(columns=["Resultat"])

# %%
myDataset.tail(3)
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O    NO2     NO STATION  VentMOD  \
# 1038     0     74   198.4   16.2  0.00811  8.349  0.942     Pla   4.0311
# 1039     0    121   191.7   16.4  0.00722  2.101  0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919  2.290  0.202     Pla   2.3022
#
#       VentANG
# 1038  0.12435
# 1039  0.00000
# 1040  0.04345

# %%
new_row = {
    "JOUR":0, 
    "O3obs":10,
    "MOCAGE":10,
    "TEMPE":10,
    "RMH20":10,
    "NO2":10,
    "NO":10,
    "STATION":"Aix",
    "VentMOD":10,
    "VentANG":10
}
myDataset = pd.concat([myDataset,pd.DataFrame([new_row])])

myDataset.tail(3)
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2      NO STATION  VentMOD  \
# 1039     0    121   191.7   16.4  0.00722   2.101   0.199     Pla   3.8000
# 1040     1     93   221.2   16.7  0.00919   2.290   0.202     Pla   2.3022
# 0        0     10    10.0   10.0      NaN  10.000  10.000     Aix  10.0000
#
#        VentANG  RMH20
# 1039   0.00000    NaN
# 1040   0.04345    NaN
# 0     10.00000   10.0
