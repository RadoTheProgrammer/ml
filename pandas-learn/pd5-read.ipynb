# %%
import pandas as pd
myDataset = pd.read_csv("Data/ozone.csv")
myDataset.iloc[5]
# Out:
# JOUR             0
# O3obs          150
# MOCAGE       114.3
# TEMPE         23.6
# RMH2O      0.01182
# NO2          5.316
# NO           1.343
# STATION        Aix
# VentMOD     6.3127
# VentANG    0.06341
# Name: 5, dtype: object

# %%
myDataset.iloc[5:10]
# Out:
#    JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  VentMOD  \
# 5     0    150   114.3   23.6  0.01182   5.316  1.343     Aix   6.3127
# 6     0    164   127.7   26.6  0.00937   2.841  0.550     Aix   4.8042
# 7     1    135   164.3   23.5  0.01087  15.733  2.911     Aix   4.8795
# 8     1    121   144.1   23.3  0.01168   8.807  1.867     Aix   5.1088
# 9     0    129   112.8   23.7  0.01091  18.911  4.700     Aix   5.4406
#
#    VentANG
# 5  0.06341
# 6  0.04164
# 7  0.79989
# 8  0.70226
# 9  0.94200

# %%
for index, row in myDataset.iterrows():
    print(f"La valeur d'indice [{index}] : \n{row}")
# Out:
# La valeur d'indice [0] :
# JOUR             1
# O3obs           91
# MOCAGE        93.2
# TEMPE         21.5
# RMH2O      0.00847
# NO2          1.602
# NO           0.424
# STATION        Aix
# VentMOD        9.5
# VentANG    -0.6435
# Name: 0, dtype: object
# La valeur d'indice [1] :
# JOUR             1
# O3obs          100
# MOCAGE       104.6
# TEMPE         20.2
# RMH2O      0.00881
# NO2          2.121
# NO           0.531
# STATION        Aix
# VentMOD       8.01
# VentANG   -0.04996
# Name: 1, dtype: object
# La valeur d'indice [2] :
# JOUR             0
# O3obs           82
# MOCAGE       103.6
# TEMPE         17.4
# RMH2O      0.00951
# NO2          1.657
# NO           0.467
# STATION        Aix
# VentMOD     9.3771
# VentANG   -0.12832
# Name: 2, dtype: object
# La valeur d'indice [3] :
# JOUR             0
# O3obs           94
# MOCAGE        94.8
# TEMPE         18.8
# RMH2O      0.00855
# NO2           2.35
# NO           0.701
# STATION        Aix
# ...

# %%
dayOff = myDataset.loc[myDataset["JOUR"]==1]
dayOff
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  VentMOD  \
# 0        1     91    93.2   21.5  0.00847   1.602  0.424     Aix   9.5000
# 1        1    100   104.6   20.2  0.00881   2.121  0.531     Aix   8.0100
# 7        1    135   164.3   23.5  0.01087  15.733  2.911     Aix   4.8795
# 8        1    121   144.1   23.3  0.01168   8.807  1.867     Aix   5.1088
# 13       1     83   158.9   15.4  0.01456  10.254  1.839     Aix   2.5942
# ...    ...    ...     ...    ...      ...     ...    ...     ...      ...
# 1020     1    104   123.0   18.1  0.01358   0.710  0.131     Pla   2.4739
# 1026     1    100   175.6   23.7  0.00949   1.447  0.180     Pla   4.9031
# 1027     1     90   140.5   22.3  0.00821   0.415  0.062     Pla   4.9820
# 1032     1     77   130.3   17.3  0.01306   0.814  0.124     Pla   5.7706
# 1040     1     93   221.2   16.7  0.00919   2.290  0.202     Pla   2.3022
#
#       VentANG
# 0    -0.64350
# 1    -0.04996
# 7     0.79989
# 8     0.70226
# ...

# %%
result = myDataset.loc[
    (myDataset["JOUR"]==1) &
    (myDataset["O3obs"]>=100)
]
result
# Out:
#       JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  VentMOD  \
# 1        1    100   104.6   20.2  0.00881   2.121  0.531     Aix   8.0100
# 7        1    135   164.3   23.5  0.01087  15.733  2.911     Aix   4.8795
# 8        1    121   144.1   23.3  0.01168   8.807  1.867     Aix   5.1088
# 20       1    118   113.0   26.2  0.01064   4.615  0.995     Aix   6.2769
# 21       1    130   136.3   27.2  0.00912   4.276  0.827     Aix   6.0033
# ...    ...    ...     ...    ...      ...     ...    ...     ...      ...
# 988      1    113   208.9   22.2  0.00731   5.804  0.812     Pla   9.0139
# 995      1    114   160.5   24.9  0.00770   3.407  0.542     Pla  10.4652
# 996      1    111   137.1   22.2  0.00473   3.801  0.743     Pla  11.8119
# 1020     1    104   123.0   18.1  0.01358   0.710  0.131     Pla   2.4739
# 1026     1    100   175.6   23.7  0.00949   1.447  0.180     Pla   4.9031
#
#       VentANG
# 1    -0.04996
# 7     0.79989
# 8     0.70226
# 20    0.53496
# ...

# %%
result = myDataset.loc[
    (myDataset["JOUR"]==1) &
    (myDataset["O3obs"]>=100) &
    ((myDataset["STATION"] == "Ram")|
     (myDataset["STATION"] == "Cad"))
]
result
# Out:
#      JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  VentMOD  \
# 422     1    103   100.5   20.7  0.00748   0.981  0.233     Cad  9.43660
# 428     1    203   182.0   25.4  0.01275   5.952  0.812     Cad  6.10740
# 429     1    208   188.0   25.3  0.01184   7.850  1.130     Cad  6.79560
# 446     1    106   138.0   34.1  0.01192   1.112  0.159     Cad  7.55050
# 447     1    114   157.8   32.9  0.01569   3.481  0.454     Cad  7.18470
# ..    ...    ...     ...    ...      ...     ...    ...     ...      ...
# 763     1    191   200.4   27.8  0.00856   3.482  0.367     Ram  0.30000
# 765     1    104   128.3   29.6  0.00776   2.831  0.472     Ram  3.10644
# 766     1    167   168.4   29.0  0.00648  12.671  1.801     Ram  2.60000
# 804     1    110   140.7   23.9  0.00608  11.722  1.807     Ram  1.65529
# 810     1    128   122.4   28.3  0.00878   6.638  1.015     Ram  4.60110
#
#      VentANG
# 422 -0.17038
# 428  0.69264
# 429  0.57576
# 446 -0.19999
# 447  0.60731
# ...

# %%
result.reset_index()
# Out:
#     index  JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  \
# 0     422     1    103   100.5   20.7  0.00748   0.981  0.233     Cad
# 1     428     1    203   182.0   25.4  0.01275   5.952  0.812     Cad
# 2     429     1    208   188.0   25.3  0.01184   7.850  1.130     Cad
# 3     446     1    106   138.0   34.1  0.01192   1.112  0.159     Cad
# 4     447     1    114   157.8   32.9  0.01569   3.481  0.454     Cad
# ..    ...   ...    ...     ...    ...      ...     ...    ...     ...
# 64    763     1    191   200.4   27.8  0.00856   3.482  0.367     Ram
# 65    765     1    104   128.3   29.6  0.00776   2.831  0.472     Ram
# 66    766     1    167   168.4   29.0  0.00648  12.671  1.801     Ram
# 67    804     1    110   140.7   23.9  0.00608  11.722  1.807     Ram
# 68    810     1    128   122.4   28.3  0.00878   6.638  1.015     Ram
#
#     VentMOD  VentANG
# 0   9.43660 -0.17038
# 1   6.10740  0.69264
# 2   6.79560  0.57576
# 3   7.55050 -0.19999
# ...

# %%
result.reset_index(drop=True)
# Out:
#     JOUR  O3obs  MOCAGE  TEMPE    RMH2O     NO2     NO STATION  VentMOD  \
# 0      1    103   100.5   20.7  0.00748   0.981  0.233     Cad  9.43660
# 1      1    203   182.0   25.4  0.01275   5.952  0.812     Cad  6.10740
# 2      1    208   188.0   25.3  0.01184   7.850  1.130     Cad  6.79560
# 3      1    106   138.0   34.1  0.01192   1.112  0.159     Cad  7.55050
# 4      1    114   157.8   32.9  0.01569   3.481  0.454     Cad  7.18470
# ..   ...    ...     ...    ...      ...     ...    ...     ...      ...
# 64     1    191   200.4   27.8  0.00856   3.482  0.367     Ram  0.30000
# 65     1    104   128.3   29.6  0.00776   2.831  0.472     Ram  3.10644
# 66     1    167   168.4   29.0  0.00648  12.671  1.801     Ram  2.60000
# 67     1    110   140.7   23.9  0.00608  11.722  1.807     Ram  1.65529
# 68     1    128   122.4   28.3  0.00878   6.638  1.015     Ram  4.60110
#
#     VentANG
# 0  -0.17038
# 1   0.69264
# 2   0.57576
# 3  -0.19999
# 4   0.60731
# ..      ...
# ...

# %%
myDataset["STATION"].unique()
# Out:
# array(['Aix', 'Als', 'Cad', 'Ram', 'Pla'], dtype=object)

# %%
result = myDataset.loc[myDataset["STATION"].str.contains(".a.",regex=True)]

result["STATION"].unique()
# Out:
# array(['Cad', 'Ram'], dtype=object)

# %%
vars = myDataset.columns
vars
# Out:
# Index(['JOUR', 'O3obs', 'MOCAGE', 'TEMPE', 'RMH2O', 'NO2', 'NO', 'STATION',
#        'VentMOD', 'VentANG'],
#       dtype='object')

# %%
VentMOD = myDataset["VentMOD"]
VentMOD
# Out:
# 0       9.5000
# 1       8.0100
# 2       9.3771
# 3       9.4578
# 4       7.8791
#          ...
# 1036    4.8052
# 1037    2.7203
# 1038    4.0311
# 1039    3.8000
# 1040    2.3022
# Name: VentMOD, Length: 1041, dtype: float64

# %%
data=myDataset[["JOUR", "VentMOD"]]
data
# Out:
#       JOUR  VentMOD
# 0        1   9.5000
# 1        1   8.0100
# 2        0   9.3771
# 3        0   9.4578
# 4        0   7.8791
# ...    ...      ...
# 1036     0   4.8052
# 1037     0   2.7203
# 1038     0   4.0311
# 1039     0   3.8000
# 1040     1   2.3022
#
# [1041 rows x 2 columns]

# %%
myDataset.iloc[8,2]
# Out:
# 144.1
